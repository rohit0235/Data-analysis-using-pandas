# %% [markdown]
# <a href="https://colab.research.google.com/github/rohit0235/Data-analysis-using-pandas/blob/main/panda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("HELLO  WORLD")
# Out:
# HELLO  WORLD

# %%
import pandas as pd

# %%
df=pd.read_csv('https://query.data.world/s/442hmws6ei6qe3xfgbp6tdemtxxz7p');
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.head()
df.tail(10)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7033  9767-FFLEM    Male              0      No         No      38
# 7034  0639-TSIQW  Female              0      No         No      67
# 7035  8456-QDAVC    Male              0      No         No      19
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7037  2569-WGERO  Female              0      No         No      72
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 7033          Yes                No     Fiber optic                   No  ...
# ...

# %%
df['gender']=='Female'
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 7038    False
# 7039     True
# 7040     True
# 7041    False
# 7042    False
# Name: gender, Length: 7043, dtype: bool

# %%
df[df['gender']=='Female']
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 7     6713-OKOMC  Female              0      No         No      10
# 8     7892-POOKP  Female              0     Yes         No      28
# ...          ...     ...            ...     ...        ...     ...
# 7034  0639-TSIQW  Female              0      No         No      67
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7037  2569-WGERO  Female              0      No         No      72
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 0              No  No phone service             DSL                   No  ...
# ...

# %%
df[ (df['gender']=='Male') & (df['tenure']>20) & (df['Churn'] == 'No')]
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE   Male              0      No         No      34
# 3     7795-CFOCW   Male              0      No         No      45
# 6     1452-KIOVK   Male              0      No        Yes      22
# 9     6388-TABGU   Male              0      No        Yes      62
# 12    8091-TTVAX   Male              0     Yes         No      58
# ...          ...    ...            ...     ...        ...     ...
# 7024  7398-LXGYX   Male              0     Yes         No      44
# 7031  3605-JISKB   Male              1     Yes         No      55
# 7033  9767-FFLEM   Male              0      No         No      38
# 7038  6840-RESVB   Male              0     Yes        Yes      24
# 7042  3186-AJIEK   Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 1             Yes                No             DSL            Yes  ...
# ...

# %%
# unique value
df['PaymentMethod'].nunique()
# Out:
# 4

# %%
# unique value
df['PaymentMethod'].unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
df['PaymentMethod'].value_counts()
# Out:
# PaymentMethod
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: count, dtype: int64

# %%
#number of rows
df.shape[0]
# Out:
# 7043

# %%
#percentage of rows
df['PaymentMethod'].value_counts()/df.shape[0]  *100
# Out:
# PaymentMethod
# Electronic check             33.579441
# Mailed check                 22.887974
# Bank transfer (automatic)    21.922476
# Credit card (automatic)      21.610109
# Name: count, dtype: float64

# %%
df.groupby("gender").agg({'tenure':'mean'})
# Out:
#            tenure
# gender
# Female  32.244553
# Male    32.495359

# %%
df.groupby(['gender', 'Churn','Contract']).agg({'tenure':'mean', 'customerID':'count'})
# Out:
#                                 tenure  customerID
# gender Churn Contract
# Female No    Month-to-month  21.449677        1083
#              One year        42.194401         643
#              Two year        56.064399         823
#        Yes   Month-to-month  13.503563         842
#              One year        44.600000          75
#              Two year        56.909091          22
# Male   No    Month-to-month  20.636763        1137
#              One year        41.170181         664
#              Two year        57.140777         824
#        Yes   Month-to-month  14.548585         813
#              One year        45.263736          91
#              Two year        64.961538          26

# %%
df.groupby(['Contract','Churn']).agg({'MonthlyCharges':'mean'})
# Out:
#                       MonthlyCharges
# Contract       Churn
# Month-to-month No          61.462635
#                Yes         73.019396
# One year       No          62.508148
#                Yes         85.050904
# Two year       No          60.012477
#                Yes         86.777083

# %%
#using this we can group the data in both row  and column

df.pivot_table(index = 'Churn', columns = 'Contract', values ='MonthlyCharges', aggfunc = 'mean')
# Out:
# Contract  Month-to-month   One year   Two year
# Churn
# No             61.462635  62.508148  60.012477
# Yes            73.019396  85.050904  86.777083

# %%
# df.drop(columns = 'customerID', inplace = True)

df.drop(columns = 'customerID')
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
df.drop(index = 2)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.drop(columns = ['customerID', 'Churn'], index = 2)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# 5     Female              0      No         No       8          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
df.drop("customerID", axis = 1)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
df.drop(2, axis = 0)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df['tenure'].min()
# Out:
# 0

# %%
df['tenure'].max()
# Out:
# 72

# %%
def t_b(x):
  if x<5:
    return "D"
  elif x>=5 and x<20:
    return "C"
  elif x>=20 and x<50:
    return "B"
  else:
    return "A"

# %%
df['tenure_b']=df['tenure'].apply(t_b)

# %%
df['tenure'].apply(lambda x: "D" if x<5 else ("C" if x>=5 and x<20 else ("B" if x>=20 and x<50 else "A")))
# Out:
# 0       D
# 1       B
# 2       D
# 3       B
# 4       D
#        ..
# 7038    B
# 7039    A
# 7040    C
# 7041    D
# 7042    A
# Name: tenure, Length: 7043, dtype: object

# %% [markdown]
# #control the attribute , generate plots - matplotlib
# #seaborn - generate a plot   not helpful in background  much much easier than matplotlib
#
#
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.displot(df['tenure'])

# %%
sns.displot(df['tenure'],kind='kde',height=3 ,aspect=1.5)

# %%
plt.figure(figsize=(5,2))
sns.boxplot(x=df['tenure'])
# Out:
# <Axes: xlabel='tenure'>

# %%
plt.figure(figsize=(5,2))
sns.boxplot(x=df['MonthlyCharges'])
# Out:
# <Axes: xlabel='MonthlyCharges'>

# %%
plt.figure(figsize=(5,2))
sns.boxplot(x=df[df['Churn']=='No']['MonthlyCharges'])
# Out:
# <Axes: xlabel='MonthlyCharges'>

# %%
plt.figure(figsize=(5,2))
sns.boxplot(x=df[df['Churn']=='Yes']['MonthlyCharges'])
# Out:
# <Axes: xlabel='MonthlyCharges'>

# %% [markdown]
# MULTIPLE PLOT ![image.png](data:image/png;base64,...)

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.title("Churn monthlycharge");
sns.boxplot(x=df[df['Churn']=='Yes']['MonthlyCharges'])
plt.subplot(1, 2, 2)
plt.title("No Churn tenure");
sns.boxplot(x=df[df['Churn']=='No']['tenure'])
# Out:
# <Axes: title={'center': 'No Churn tenure'}, xlabel='tenure'>

# %%
sns.boxplot(x=df['Churn'],y=df['MonthlyCharges'])
# Out:
# <Axes: xlabel='Churn', ylabel='MonthlyCharges'>

# %% [markdown]
# categorical chart

# %%
x=['A','B','C']
y=[100,65,25]

# %%
sns.barplot(x=x,y=y)
# Out:
# <Axes: >

# %%
a=df['gender'].value_counts().reset_index()

# %%
sns.barplot(x=a['count'],y=a['gender'])
plt.xlabel('gender')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...         Yes
# 4                No     Fiber optic             No  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %% [markdown]
# Day-**3**
#
# WEB SCRAPING

# %%
import requests

# %%
url='https://en.wikipedia.org/wiki/Human_body_weight' #take url

# %%
response=requests.get(url,headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36'})

# %%
response #200 means ok
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>Human body weight - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector
# ...

# %%
from bs4 import BeautifulSoup #search

# %%
out=BeautifulSoup(response.text,'html.parser')

# %%
out
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Human body weight - Wikipedia</title>
# ...

# %%
out.find('table',{'class':'wikitable sortable'})
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Region
# </th>
# <th>Adult <br/> population<br/>(millions)
# </th>
# <th>Average weight
# </th>
# <th>% <br/> Overweight
# </th>
# <th><style data-mw-deduplicate="TemplateStyles:r1038841319">.mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}</style><span class="rt-commentedText tooltip tooltip-dotted" title="Reference">Ref</span>
# </th></tr>
# <tr>
# <td><a href="/wiki/Africa" title="Africa">Africa</a></td>
# <td>535</td>
# <td>60.7 kg (133.8 lb)</td>
# <td>28.9%</td>
# <td><sup class="reference" id="cite_ref-biomed_11-0"><a href="#cite_note-biomed-11"><span class="cite-bracket">[</span>11<span class="cite-bracket">]</span></a></sup>
# </td></tr>
# <tr>
# <td><a href="/wiki/Asia" title="Asia">Asia</a></td>
# <td>2,815</td>
# <td>57.7 kg (127.2 lb)</td>
# <td>24.2%</td>
# ...

# %%
l=out.find_all('table',{'class':'wikitable sortable'})

# %%
l[0]
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Region
# </th>
# <th>Adult <br/> population<br/>(millions)
# </th>
# <th>Average weight
# </th>
# <th>% <br/> Overweight
# </th>
# <th><style data-mw-deduplicate="TemplateStyles:r1038841319">.mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}</style><span class="rt-commentedText tooltip tooltip-dotted" title="Reference">Ref</span>
# </th></tr>
# <tr>
# <td><a href="/wiki/Africa" title="Africa">Africa</a></td>
# <td>535</td>
# <td>60.7 kg (133.8 lb)</td>
# <td>28.9%</td>
# <td><sup class="reference" id="cite_ref-biomed_11-0"><a href="#cite_note-biomed-11"><span class="cite-bracket">[</span>11<span class="cite-bracket">]</span></a></sup>
# </td></tr>
# <tr>
# <td><a href="/wiki/Asia" title="Asia">Asia</a></td>
# <td>2,815</td>
# <td>57.7 kg (127.2 lb)</td>
# <td>24.2%</td>
# ...

# %%
a=pd.read_html(str(l[0]))
# Out:
# <ipython-input-54-99c24f886fbf>:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   a=pd.read_html(str(l[0]))

# %%
df=a[0]

# %%
df.head()
# Out:
#                             Region  Adult population (millions)  \
# 0                           Africa                          535
# 1                             Asia                         2815
# 2                           Europe                          606
# 3  Latin America and the Caribbean                          386
# 4                    North America                          263
#
#        Average weight % Overweight   Ref
# 0  60.7 kg (133.8 lb)        28.9%  [11]
# 1  57.7 kg (127.2 lb)        24.2%  [11]
# 2  70.8 kg (156.1 lb)        55.6%  [11]
# 3  67.9 kg (149.7 lb)        57.9%  [11]
# 4  80.7 kg (177.9 lb)        73.9%  [11]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Region                       7 non-null      object
#  1   Adult population (millions)  7 non-null      int64
#  2   Average weight               7 non-null      object
#  3   % Overweight                 7 non-null      object
#  4   Ref                          7 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 408.0+ bytes

# %%
df.drop(columns='Ref',inplace=True)

# %%
df.head()
# Out:
#                             Region  Adult population (millions)  \
# 0                           Africa                          535
# 1                             Asia                         2815
# 2                           Europe                          606
# 3  Latin America and the Caribbean                          386
# 4                    North America                          263
#
#        Average weight % Overweight
# 0  60.7 kg (133.8 lb)        28.9%
# 1  57.7 kg (127.2 lb)        24.2%
# 2  70.8 kg (156.1 lb)        55.6%
# 3  67.9 kg (149.7 lb)        57.9%
# 4  80.7 kg (177.9 lb)        73.9%

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Region                       7 non-null      object
#  1   Adult population (millions)  7 non-null      int64
#  2   Average weight               7 non-null      object
#  3   % Overweight                 7 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 352.0+ bytes

# %%
df['Average weight']
# Out:
# 0    60.7 kg (133.8 lb)
# 1    57.7 kg (127.2 lb)
# 2    70.8 kg (156.1 lb)
# 3    67.9 kg (149.7 lb)
# 4    80.7 kg (177.9 lb)
# 5    74.1 kg (163.4 lb)
# 6    62.0 kg (136.7 lb)
# Name: Average weight, dtype: object

# %%
a='60.7 kg (133.8 lb)'

# %%
a.split(' ')[0]
# Out:
# '60.7'

# %%
import re

# %%
float(re.findall("\d+\.\d+",a.split(' ')[0])[0])
# Out:
# 60.7

# %%
df['Average weight'].apply(lambda x:float(re.findall("\d+\.\d+",x.split(' ')[0])[0]))
# Out:
# 0    60.7
# 1    57.7
# 2    70.8
# 3    67.9
# 4    80.7
# 5    74.1
# 6    62.0
# Name: Average weight, dtype: float64

# %%
df.head()
# Out:
#                             Region  Adult population (millions)  \
# 0                           Africa                          535
# 1                             Asia                         2815
# 2                           Europe                          606
# 3  Latin America and the Caribbean                          386
# 4                    North America                          263
#
#        Average weight % Overweight
# 0  60.7 kg (133.8 lb)        28.9%
# 1  57.7 kg (127.2 lb)        24.2%
# 2  70.8 kg (156.1 lb)        55.6%
# 3  67.9 kg (149.7 lb)        57.9%
# 4  80.7 kg (177.9 lb)        73.9%
